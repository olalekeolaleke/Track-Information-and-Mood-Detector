# %%
# Importing Dependencies

import pandas as pd
import os
from sqlalchemy import create_engine
import warnings 
warnings.simplefilter("ignore")

# %%
# Creating csv path and loading first data in Pandas DataFrame

csv_path = ("data/genres_v2.csv")
song_df = pd.read_csv(csv_path)
song_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# ...

# %%
# Creating csv path and loading second data in Pandas DataFrame

csv_path = ("data/data_moods.csv")
data_mood = pd.read_csv(csv_path)
data_mood.head()
# Out:
#                                           name                        album  \
# 0                                         1999                         1999
# 1                                           23                           23
# 2                                     9 Crimes                            9
# 3                               99 Luftballons               99 Luftballons
# 4  A Boy Brushed Red Living In Black And White  They're Only Chasing Safety
#
#            artist                      id release_date  popularity  length  \
# 0          Prince  2H7PHVdQ3mXqEHXcvclTB0   1982-10-27          68  379266
# 1  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP   2007-04-16          43  318800
# 2     Damien Rice  5GZEeowhvSieFDiR8fQ2im   2006-11-06          60  217946
# 3            Nena  6HA97v4wEGQ5TUClRM0XLc   1984-08-21           2  233000
# 4       Underoath  47IWLfIKOKhFnz1FUEUIkE   2004-01-01          60  268000
#
# ...

# %% [markdown]
# ### Data Cleaning and Transformation

# %%
# Dropping unwanted columns 

song_df.drop(["uri","track_href","analysis_url","type","title","Unnamed: 0"], axis=1, inplace = True)

# %%
# Dropping rows with nan values

data_df = song_df.dropna(axis=0)

# %%
# Converting duration ms to min

data_df['duration_min'] = data_df['duration_ms']/60000
data_df.drop('duration_ms',axis=1,inplace=True)

# %%
# # making the country column as the first column

# first_column = data_df.pop('song_name')
  
# # insert column using insert(position,column_name,
# # first_column) function
# data_df.insert(0, 'song_name', first_column)
# data_df

# %% [markdown]
# ### Connecting to local database

# %%
# Connecting to local database

protocol = 'postgresql'
username = ''
password = ''
host = 'localhost'
port = 5432
database_name = 'dataparty_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
#engine = create_engine(rds_connection_string)
engine = create_engine('postgresql+psycopg2://postgres:akinbola1984@localhost/dataparty_db')

# %%
# Checking for tables

engine.table_names()
# Out:
# ['music_data', 'data_mood']

# %% [markdown]
# ### Using pandas to load csv converted DataFrame into database

# %%
# Loading the reported_cases csv dataframe into prosgresql table

data_df.to_sql(name='music_data', con=engine, if_exists='replace', index=False)
data_mood.to_sql(name='data_mood', con=engine, if_exists='replace', index=False)
# Out:
# 686

# %% [markdown]
# ### Confirming data has been added by querying the music data table

# %%
# Dispalying the music_data table from the prosgresql database

pd.read_sql_query('select * from music_data', con=engine).head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.013400    0.0556   0.3890  156.985  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  115.080  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  218.050  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  186.948  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  147.988  4jCeguq9rMTlbMmPHuO7S3
#
#    time_signature      genre                                      song_name  \
# ...

# %%
# Dispalying the data_mood table from the prosgresql database

pd.read_sql_query('select * from data_mood', con=engine).head()
# Out:
#                                           name                        album  \
# 0                                         1999                         1999
# 1                                           23                           23
# 2                                     9 Crimes                            9
# 3                               99 Luftballons               99 Luftballons
# 4  A Boy Brushed Red Living In Black And White  They're Only Chasing Safety
#
#            artist                      id release_date  popularity  length  \
# 0          Prince  2H7PHVdQ3mXqEHXcvclTB0   1982-10-27          68  379266
# 1  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP   2007-04-16          43  318800
# 2     Damien Rice  5GZEeowhvSieFDiR8fQ2im   2006-11-06          60  217946
# 3            Nena  6HA97v4wEGQ5TUClRM0XLc   1984-08-21           2  233000
# 4       Underoath  47IWLfIKOKhFnz1FUEUIkE   2004-01-01          60  268000
#
# ...

# %% [markdown]
# ### Exporting Pandas DataFrame into csv

# %%
# Exporting Pandas DataFrame into csv
# os.makedirs('data', exist_ok=True)  
data_df.to_csv('data/music_data.csv', index=False)
